# %% [markdown]
# # Test de Generador de Reportes

# %%
# Downoloading libraries.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading file to process

# %%
# Loading CSV file with updated status. It is important to note that the best way to produce reports for each month is to create a new jupyter notebook with the updated CSV file. 
# In that sense, keeping backups of past CSV will be important to keep a registry of all passed months.
data = pd.read_csv("./Status Sofía 2025 - TEST1.csv")
data
# Out:
#     Fecha de Solicitud Fecha de Entrega  \
# 0            29/5/2024              NaN
# 1            13/1/2025        19/2/2025
# 2            13/1/2025        19/2/2025
# 3            13/1/2025        13/2/2025
# 4            13/1/2025        13/2/2025
# ..                 ...              ...
# 945                NaN              NaN
# 946                NaN              NaN
# 947                NaN              NaN
# 948                NaN              NaN
# 949                NaN              NaN
#
#                                              Solicitud Linea de Productos  \
# 0               87-24/ Sofía/ Campaña Consumo de Cerdo              Cerdo
# 1     Sofía/ Campaña Consumo de Cerdo/ TVC 30'' y 15''              Cerdo
# 2              Sofía/ Campaña Consumo de Cerdo/ Jingle              Cerdo
# 3    Sofía/ Campaña Consumo de Cerdo/ KV 1 Medallon...              Cerdo
# 4    Sofía/ Campaña Consumo de Cerdo/ KV 2 Carne Mo...              Cerdo
# ..                                                 ...                ...
# 945     841-25/Sofía/Institucional/Brief 50 Años Sofía                NaN
# 946                 842-25/Sofía/BRIEF | CARNAVAL 2026                NaN
# 947  844-25/Sofía/Procesados/Diseño bolsa procesado...                NaN
# 948       843-25/Sofia/Digital/Nada es lo que parece 3                NaN
# 949          845-25/Sofía/Digital/Arte salutación Beni                NaN
#
#           Tipo  Piezas     Estado Responsable             Solicitante  \
# 0      Campaña     1.0  Entregado      Sergio  Maria Isabel Anglarill
# 1    Comercial     2.0  Entregado      Sergio  Maria Isabel Anglarill
# 2         Cuña     1.0  Entregado      Sergio  Maria Isabel Anglarill
# 3           KV     1.0  Entregado        René  Maria Isabel Anglarill
# 4           KV     1.0  Entregado        René  Maria Isabel Anglarill
# ..         ...     ...        ...         ...                     ...
# 945        NaN     NaN        NaN         NaN                     NaN
# 946        NaN     NaN        NaN         NaN                     NaN
# 947        NaN     NaN        NaN         NaN                     NaN
# 948        NaN     NaN        NaN         NaN                     NaN
# 949        NaN     NaN        NaN         NaN                     NaN
#
#                      Trabajo  ...  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0        Creatvidad + Diseño  ...          NaN          NaN          NaN
# 1                Creatividad  ...          NaN          NaN          NaN
# 2    Creatividad + Redacción  ...          NaN          NaN          NaN
# 3                     Diseño  ...          NaN          NaN          NaN
# 4                     Diseño  ...          NaN          NaN          NaN
# ..                       ...  ...          ...          ...          ...
# 945                      NaN  ...          NaN          NaN          NaN
# 946                      NaN  ...          NaN          NaN          NaN
# 947                      NaN  ...          NaN          NaN          NaN
# 948                      NaN  ...          NaN          NaN          NaN
# 949                      NaN  ...          NaN          NaN          NaN
#
#      Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 945          NaN          NaN          NaN          NaN          NaN
# 946          NaN          NaN          NaN          NaN          NaN
# 947          NaN          NaN          NaN          NaN          NaN
# 948          NaN          NaN          NaN          NaN          NaN
# 949          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 28  Unnamed: 29
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 945          NaN          NaN
# 946          NaN          NaN
# 947          NaN          NaN
# 948          NaN          NaN
# 949          NaN          NaN
#
# [950 rows x 30 columns]

# %% [markdown]
# ## Pre-processing data

# %%
#Removing all columns with nan values
df_cleaned = data.dropna(axis=1, how='all')

# %%
#Removing column 29 with nan values
df_cleaned = df_cleaned.drop(["Unnamed: 29"], axis = 1)

# %%
#Printing dataframe to check if the nan columns have been removed
df_cleaned
# Out:
#     Fecha de Solicitud Fecha de Entrega  \
# 0            29/5/2024              NaN
# 1            13/1/2025        19/2/2025
# 2            13/1/2025        19/2/2025
# 3            13/1/2025        13/2/2025
# 4            13/1/2025        13/2/2025
# ..                 ...              ...
# 945                NaN              NaN
# 946                NaN              NaN
# 947                NaN              NaN
# 948                NaN              NaN
# 949                NaN              NaN
#
#                                              Solicitud Linea de Productos  \
# 0               87-24/ Sofía/ Campaña Consumo de Cerdo              Cerdo
# 1     Sofía/ Campaña Consumo de Cerdo/ TVC 30'' y 15''              Cerdo
# 2              Sofía/ Campaña Consumo de Cerdo/ Jingle              Cerdo
# 3    Sofía/ Campaña Consumo de Cerdo/ KV 1 Medallon...              Cerdo
# 4    Sofía/ Campaña Consumo de Cerdo/ KV 2 Carne Mo...              Cerdo
# ..                                                 ...                ...
# 945     841-25/Sofía/Institucional/Brief 50 Años Sofía                NaN
# 946                 842-25/Sofía/BRIEF | CARNAVAL 2026                NaN
# 947  844-25/Sofía/Procesados/Diseño bolsa procesado...                NaN
# 948       843-25/Sofia/Digital/Nada es lo que parece 3                NaN
# 949          845-25/Sofía/Digital/Arte salutación Beni                NaN
#
#           Tipo  Piezas     Estado Responsable             Solicitante  \
# 0      Campaña     1.0  Entregado      Sergio  Maria Isabel Anglarill
# 1    Comercial     2.0  Entregado      Sergio  Maria Isabel Anglarill
# 2         Cuña     1.0  Entregado      Sergio  Maria Isabel Anglarill
# 3           KV     1.0  Entregado        René  Maria Isabel Anglarill
# 4           KV     1.0  Entregado        René  Maria Isabel Anglarill
# ..         ...     ...        ...         ...                     ...
# 945        NaN     NaN        NaN         NaN                     NaN
# 946        NaN     NaN        NaN         NaN                     NaN
# 947        NaN     NaN        NaN         NaN                     NaN
# 948        NaN     NaN        NaN         NaN                     NaN
# 949        NaN     NaN        NaN         NaN                     NaN
#
#                      Trabajo
# 0        Creatvidad + Diseño
# 1                Creatividad
# 2    Creatividad + Redacción
# 3                     Diseño
# 4                     Diseño
# ..                       ...
# 945                      NaN
# 946                      NaN
# 947                      NaN
# 948                      NaN
# 949                      NaN
#
# [950 rows x 10 columns]

# %% [markdown]
# ## Assigning datatypes to columns in the dataframe

# %%
# Changing data types from columns
df_cleaned.columns = df_cleaned.columns.str.strip()

# Date format
df_cleaned['Fecha de Solicitud'] = pd.to_datetime(df_cleaned['Fecha de Solicitud'], format='%d/%m/%Y', errors='coerce')
df_cleaned['Fecha de Entrega'] = pd.to_datetime(df_cleaned['Fecha de Entrega'], format='%d/%m/%Y', errors='coerce')

# String
cols_to_convert = ['Solicitud', 'Linea de Productos', 'Tipo', 'Estado', 'Responsable', 'Solicitante', 'Trabajo']
df_cleaned[cols_to_convert] = df_cleaned[cols_to_convert].astype('string')

# Ints
df_cleaned['Piezas'] = pd.to_numeric(df_cleaned['Piezas'], errors='coerce').astype('Int64')

# %% [markdown]
# ## Function to assign a week number to each entry

# %%
# Creating a new column to assign a week of the month given the date.
df_cleaned["Semana"] = df_cleaned["Fecha de Solicitud"].apply(lambda d: (d.day - 1) // 7 + 1).astype("Int64")

# %%
# Checking if datatypes have been correctly assigned
df_cleaned.dtypes
# Out:
# Fecha de Solicitud    datetime64[ns]
# Fecha de Entrega      datetime64[ns]
# Solicitud             string[python]
# Linea de Productos    string[python]
# Tipo                  string[python]
# Piezas                         Int64
# Estado                string[python]
# Responsable           string[python]
# Solicitante           string[python]
# Trabajo               string[python]
# Semana                         Int64
# dtype: object

# %%
#Printing dataframe for debugging
df_cleaned
# Out:
#     Fecha de Solicitud Fecha de Entrega  \
# 0           2024-05-29              NaT
# 1           2025-01-13       2025-02-19
# 2           2025-01-13       2025-02-19
# 3           2025-01-13       2025-02-13
# 4           2025-01-13       2025-02-13
# ..                 ...              ...
# 945                NaT              NaT
# 946                NaT              NaT
# 947                NaT              NaT
# 948                NaT              NaT
# 949                NaT              NaT
#
#                                              Solicitud Linea de Productos  \
# 0               87-24/ Sofía/ Campaña Consumo de Cerdo              Cerdo
# 1     Sofía/ Campaña Consumo de Cerdo/ TVC 30'' y 15''              Cerdo
# 2              Sofía/ Campaña Consumo de Cerdo/ Jingle              Cerdo
# 3    Sofía/ Campaña Consumo de Cerdo/ KV 1 Medallon...              Cerdo
# 4    Sofía/ Campaña Consumo de Cerdo/ KV 2 Carne Mo...              Cerdo
# ..                                                 ...                ...
# 945     841-25/Sofía/Institucional/Brief 50 Años Sofía               <NA>
# 946                 842-25/Sofía/BRIEF | CARNAVAL 2026               <NA>
# 947  844-25/Sofía/Procesados/Diseño bolsa procesado...               <NA>
# 948       843-25/Sofia/Digital/Nada es lo que parece 3               <NA>
# 949          845-25/Sofía/Digital/Arte salutación Beni               <NA>
#
#           Tipo  Piezas     Estado Responsable             Solicitante  \
# 0      Campaña       1  Entregado      Sergio  Maria Isabel Anglarill
# 1    Comercial       2  Entregado      Sergio  Maria Isabel Anglarill
# 2         Cuña       1  Entregado      Sergio  Maria Isabel Anglarill
# 3           KV       1  Entregado        René  Maria Isabel Anglarill
# 4           KV       1  Entregado        René  Maria Isabel Anglarill
# ..         ...     ...        ...         ...                     ...
# 945       <NA>    <NA>       <NA>        <NA>                    <NA>
# 946       <NA>    <NA>       <NA>        <NA>                    <NA>
# 947       <NA>    <NA>       <NA>        <NA>                    <NA>
# 948       <NA>    <NA>       <NA>        <NA>                    <NA>
# 949       <NA>    <NA>       <NA>        <NA>                    <NA>
#
#                      Trabajo  Semana
# 0        Creatvidad + Diseño       5
# 1                Creatividad       2
# 2    Creatividad + Redacción       2
# 3                     Diseño       2
# 4                     Diseño       2
# ..                       ...     ...
# 945                     <NA>    <NA>
# 946                     <NA>    <NA>
# 947                     <NA>    <NA>
# 948                     <NA>    <NA>
# 949                     <NA>    <NA>
#
# [950 rows x 11 columns]

# %% [markdown]
# ## Applying data filtering

# %%
# Filtering by date
df_enero_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-01-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-01-31")] 
df_febrero_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-02-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-02-28")] 
df_marzo_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-03-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-03-31")] 
df_abril_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-04-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-04-30")] 
df_mayo_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-05-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-05-31")] 
df_junio_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-06-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-06-30")] 
df_julio_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-07-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-07-31")] 
# df_agosto_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-08-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-08-31")] 
# df_septiembre_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-09-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-09-30")] 
# df_octubre_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-10-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-10-31")] 
# df_noviembre_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-11-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-11-30")] 
# df_diciembre_2025 = df_cleaned[(df_cleaned["Fecha de Solicitud"] >= "2025-12-01") & (df_cleaned["Fecha de Solicitud"] <= "2025-12-31")]

# %%
df_enero_2025
# Out:
#     Fecha de Solicitud Fecha de Entrega  \
# 1           2025-01-13       2025-02-19
# 2           2025-01-13       2025-02-19
# 3           2025-01-13       2025-02-13
# 4           2025-01-13       2025-02-13
# 5           2025-01-13       2025-02-13
# ..                 ...              ...
# 453         2025-01-28       2025-02-04
# 455         2025-01-28       2025-02-04
# 456         2025-01-28       2025-03-17
# 457         2025-01-29       2025-02-05
# 458         2025-01-30       2025-02-04
#
#                                              Solicitud Linea de Productos  \
# 1     Sofía/ Campaña Consumo de Cerdo/ TVC 30'' y 15''              Cerdo
# 2              Sofía/ Campaña Consumo de Cerdo/ Jingle              Cerdo
# 3    Sofía/ Campaña Consumo de Cerdo/ KV 1 Medallon...              Cerdo
# 4    Sofía/ Campaña Consumo de Cerdo/ KV 2 Carne Mo...              Cerdo
# 5    Sofía/ Campaña Consumo de Cerdo/ KV 3 Chuleta ...              Cerdo
# ..                                                 ...                ...
# 453                332-25/ Sofía/ Hamburguesa/ Polera        Hamburguesas
# 455        333-25/ Sofía/ Hamburguesa/ Ploteo Carritos       Hamburguesas
# 456             334-25/ Sofía/ Disfraz Chorizo y Huevo              Sofía
# 457               335-25/ Sofía/ Arte para Caja de Luz              Sofía
# 458  336-25/ Sofía/ RRHH/ Requerimiento de Personal...              Sofía
#
#              Tipo  Piezas     Estado Responsable             Solicitante  \
# 1       Comercial       2  Entregado      Sergio  Maria Isabel Anglarill
# 2            Cuña       1  Entregado      Sergio  Maria Isabel Anglarill
# 3              KV       1  Entregado        René  Maria Isabel Anglarill
# 4              KV       1  Entregado        René  Maria Isabel Anglarill
# 5              KV       1  Entregado        René  Maria Isabel Anglarill
# ..            ...     ...        ...         ...                     ...
# 453      Uniforme       2  Entregado       Luján               Gabriela
# 455          Arte       1  Entregado     Mariano         Carlos Gordillo
# 456      Uniforme       2  Entregado     Mariano         Carlos Gordillo
# 457          Arte       1  Entregado        René          Nathaly Tardío
# 458  Post y Story       2  Entregado        Pupi          Daniel Bellido
#
#                      Trabajo  Semana
# 1                Creatividad       2
# 2    Creatividad + Redacción       2
# 3                     Diseño       2
# 4                     Diseño       2
# 5                     Diseño       2
# ..                       ...     ...
# 453  Diseño + Arte Finalista       4
# 455  Diseño + Arte Finalista       4
# 456  Diseño + Arte Finalista       4
# 457  Diseño + Arte Finalista       5
# 458       Diseño + Redacción       5
#
# [227 rows x 11 columns]

# %%
#Saving dataframe cleaned and filtered exported to csv to processing.
df_enero_2025.to_csv("./FILTERED_STATUS/Sofia_ENE_2025.csv", index=False)
df_febrero_2025.to_csv("./FILTERED_STATUS/Sofia_FEB_2025.csv", index=False)
df_marzo_2025.to_csv("./FILTERED_STATUS/Sofia_MAR_2025.csv", index=False)
df_abril_2025.to_csv("./FILTERED_STATUS/Sofia_ABR_2025.csv", index=False)
df_mayo_2025.to_csv("./FILTERED_STATUS/Sofia_MAY_2025.csv", index=False)
df_julio_2025.to_csv("./FILTERED_STATUS/Sofia_JUN_2025.csv", index=False)
df_junio_2025.to_csv("./FILTERED_STATUS/Sofia_JUL_2025.csv", index=False)

# %% [markdown]
# # CREATING Aggregated Dataframe

# %%
data = {
    "Solicitudes_recibidas" : np.nan,
    "Piezas_solicitadas"    : np.nan,
    "Piezas_entregadas"     : np.nan,
    "Piezas_canceladas"     : np.nan,
    "Semana1_solicitadas"   : np.nan,
    "Semana1_entregadas"    : np.nan,
    "Semana2_solicitadas"   : np.nan,
    "Semana2_entregadas"    : np.nan,
    "Semana3_solicitadas"   : np.nan,
    "Semana3_entregadas"    : np.nan,
    "Semana4_solicitadas"   : np.nan,
    "Semana4_entregadas"    : np.nan
}

indices = ["ENE", "FEB", "MAR", "ABR", "MAY", "JUN", "JUL", "AGO", "SEP", "OCT", "NOV", "DIC"]
df_aggregated = pd.DataFrame(data, indices)
df_aggregated
# Out:
#      Solicitudes_recibidas  Piezas_solicitadas  Piezas_entregadas  \
# ENE                    NaN                 NaN                NaN
# FEB                    NaN                 NaN                NaN
# MAR                    NaN                 NaN                NaN
# ABR                    NaN                 NaN                NaN
# MAY                    NaN                 NaN                NaN
# JUN                    NaN                 NaN                NaN
# JUL                    NaN                 NaN                NaN
# AGO                    NaN                 NaN                NaN
# SEP                    NaN                 NaN                NaN
# OCT                    NaN                 NaN                NaN
# NOV                    NaN                 NaN                NaN
# DIC                    NaN                 NaN                NaN
#
#      Piezas_canceladas  Semana1_solicitadas  Semana1_entregadas  \
# ENE                NaN                  NaN                 NaN
# FEB                NaN                  NaN                 NaN
# MAR                NaN                  NaN                 NaN
# ABR                NaN                  NaN                 NaN
# MAY                NaN                  NaN                 NaN
# JUN                NaN                  NaN                 NaN
# JUL                NaN                  NaN                 NaN
# AGO                NaN                  NaN                 NaN
# SEP                NaN                  NaN                 NaN
# OCT                NaN                  NaN                 NaN
# NOV                NaN                  NaN                 NaN
# DIC                NaN                  NaN                 NaN
#
#      Semana2_solicitadas  Semana2_entregadas  Semana3_solicitadas  \
# ENE                  NaN                 NaN                  NaN
# FEB                  NaN                 NaN                  NaN
# MAR                  NaN                 NaN                  NaN
# ABR                  NaN                 NaN                  NaN
# MAY                  NaN                 NaN                  NaN
# JUN                  NaN                 NaN                  NaN
# JUL                  NaN                 NaN                  NaN
# AGO                  NaN                 NaN                  NaN
# SEP                  NaN                 NaN                  NaN
# OCT                  NaN                 NaN                  NaN
# NOV                  NaN                 NaN                  NaN
# DIC                  NaN                 NaN                  NaN
#
#      Semana3_entregadas  Semana4_solicitadas  Semana4_entregadas
# ENE                 NaN                  NaN                 NaN
# FEB                 NaN                  NaN                 NaN
# MAR                 NaN                  NaN                 NaN
# ABR                 NaN                  NaN                 NaN
# MAY                 NaN                  NaN                 NaN
# JUN                 NaN                  NaN                 NaN
# JUL                 NaN                  NaN                 NaN
# AGO                 NaN                  NaN                 NaN
# SEP                 NaN                  NaN                 NaN
# OCT                 NaN                  NaN                 NaN
# NOV                 NaN                  NaN                 NaN
# DIC                 NaN                  NaN                 NaN

# %% [markdown]
# ## FUNCTION: EXTRACT PIEZAS SOLICITADAS v. ENTREGADAS

# %%
def to_aggregated(file):
    splitting = file.split("_") #Splitting filename
    month = splitting[2] #getting month

    working_df = pd.read_csv(file) #loading the monthly csv

    df_aggregated.loc[month, "Solicitudes_recibidas"] = working_df["Solicitud"].count().astype(int)

    #Getting the total number of Piezas_solicitadas
    df_aggregated.loc[month, "Piezas_solicitadas"] = working_df["Piezas"].sum().astype(int)
    
    #DF with the count of all Piezas_solicitadas and their status
    #0: Entregado, 1: Cancelado, 2:En cliente, 3:Stand by
    piezas_por_estado = working_df["Estado"].value_counts()

    #Adding data to Piezas_entregadas and Piezas_canceladas columns in aggregated dataframe
    df_aggregated.loc[month, "Piezas_entregadas"] = piezas_por_estado.iloc[0]
    df_aggregated.loc[month, "Piezas_canceladas"] = piezas_por_estado.iloc[1]    
    
to_aggregated("./FILTERED_STATUS/Sofia_ENE_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_FEB_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_MAR_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_ABR_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_MAY_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_JUN_2025.csv")
to_aggregated("./FILTERED_STATUS/Sofia_JUL_2025.csv")

df_aggregated
# Out:
#      Solicitudes_recibidas  Piezas_solicitadas  Piezas_entregadas  \
# ENE                  227.0               327.0              202.0
# FEB                   94.0               146.0               81.0
# MAR                  116.0               139.0               89.0
# ABR                   75.0                97.0               67.0
# MAY                  147.0               328.0              108.0
# JUN                   40.0               118.0               33.0
# JUL                   50.0               120.0               44.0
# AGO                    NaN                 NaN                NaN
# SEP                    NaN                 NaN                NaN
# OCT                    NaN                 NaN                NaN
# NOV                    NaN                 NaN                NaN
# DIC                    NaN                 NaN                NaN
#
#      Piezas_canceladas  Semana1_solicitadas  Semana1_entregadas  \
# ENE               19.0                  NaN                 NaN
# FEB                5.0                  NaN                 NaN
# MAR               14.0                  NaN                 NaN
# ABR                3.0                  NaN                 NaN
# MAY               25.0                  NaN                 NaN
# JUN                3.0                  NaN                 NaN
# JUL                2.0                  NaN                 NaN
# AGO                NaN                  NaN                 NaN
# SEP                NaN                  NaN                 NaN
# OCT                NaN                  NaN                 NaN
# NOV                NaN                  NaN                 NaN
# DIC                NaN                  NaN                 NaN
#
#      Semana2_solicitadas  Semana2_entregadas  Semana3_solicitadas  \
# ENE                  NaN                 NaN                  NaN
# FEB                  NaN                 NaN                  NaN
# MAR                  NaN                 NaN                  NaN
# ABR                  NaN                 NaN                  NaN
# MAY                  NaN                 NaN                  NaN
# JUN                  NaN                 NaN                  NaN
# JUL                  NaN                 NaN                  NaN
# AGO                  NaN                 NaN                  NaN
# SEP                  NaN                 NaN                  NaN
# OCT                  NaN                 NaN                  NaN
# NOV                  NaN                 NaN                  NaN
# DIC                  NaN                 NaN                  NaN
#
#      Semana3_entregadas  Semana4_solicitadas  Semana4_entregadas
# ENE                 NaN                  NaN                 NaN
# FEB                 NaN                  NaN                 NaN
# MAR                 NaN                  NaN                 NaN
# ABR                 NaN                  NaN                 NaN
# MAY                 NaN                  NaN                 NaN
# JUN                 NaN                  NaN                 NaN
# JUL                 NaN                  NaN                 NaN
# AGO                 NaN                  NaN                 NaN
# SEP                 NaN                  NaN                 NaN
# OCT                 NaN                  NaN                 NaN
# NOV                 NaN                  NaN                 NaN
# DIC                 NaN                  NaN                 NaN
